# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
from tqdm import tqdm
import time
import math

# %%
def get_price(bs_flat):
    return re.sub(r'\xa0','', bs_flat.find('span', attrs={
                'itemprop':'price'
            }).attrs['content']).replace('₽/мес.','')

# %%
def get_total_offers(soup):
    text = soup.find('div', attrs={'class': re.compile('.*totalOffers.*')}).text
    return int(''.join(re.findall(r'\d+', text)))

# %%
def get_total_pages(total_offers):
    return math.ceil(total_offers/28)

# %%
class main_page_parser:
    
    def __init__(self, url, headers):
        self.url = url
        self.headers  = headers
        self.soup = self.get_soup()
        self.flat_ids = self.get_flat_ids()
        self.href, self.price = self.get_page_price_href()
        
    def get_soup(self):
        resp = requests.get(self.url, headers=self.headers)
        soup = BeautifulSoup(resp.text)
        return soup
    
    def get_flat_ids(self):
        room_url = re.compile('https://www.cian.ru/rent/flat/[0-9]*')
        container = re.compile('.*--info-container--.*')
        info_containers = self.soup.find_all('div', attrs={
                        'class':container
                    })
        flat_ids = []
        for container in info_containers:
            href = container.find('a', {'href': room_url,
                                        'class': re.compile('.*--header--.*')
                                       }
                                 ).attrs['href']
            flat_id = re.search(r'[0-9]+', href).group()
            flat_ids.append(flat_id)
        return flat_ids
    
    def get_page_price_href(self):
        room_url = re.compile('https://www.cian.ru/rent/flat/[0-9]*')
        container = re.compile('.*--info-container--.*')
        info_containers = self.soup.find_all('div', attrs={
                        'class':container
                    })
        href_dict = {}
        price_dict = {}
        for container in info_containers:
            href = container.find('a', {'href': room_url,
                                        'class': re.compile('.*--header--.*')
                                       }
                                 ).attrs['href']
                        
            price = container.find('div', re.compile('.*--header--.*')).text.replace('₽/мес.','').replace(' ','')
            flat_id = re.search(r'[0-9]+', href).group()
            href_dict[flat_id] = href
            price_dict[flat_id] = price
        return href_dict, price_dict

# %%
class flat_page_parser:
    
    def __init__(self, url, headers):
        self.url = url
        self.headers = headers
        self.soup = self.get_soup()
        self.more_price_info = self.get_more_price_info()
        self.main_info = self.get_main_info()
        self.address = self.get_address()
        self.undergrounds = self.get_undergrounds()
        self.house = self.house_properties()
        self.flat_attrs = self.get_flat_attrs()
        self.flat_properties = self.get_flat_properties()
        self.short_description = self.get_short_description()
        self.main_description = self.get_main_description()
        
    def get_soup(self):
        request = requests.get(self.url)
        soup = BeautifulSoup(request.text)
        return soup
    
    def get_more_price_info(self):
        dop_info = re.compile(r'.*more_price_rent.*')
        return re.sub(r'\xa0', ' ', self.soup.find('div', attrs={
                            'class': dop_info
                        }).text)

    def get_main_info(self):
        more_info = re.compile(r'.*--info-block--.*')
        info = self.soup.find('div', attrs={
            'class': more_info
        })

        info_re = re.compile(r'.*--info--.*')
        info_title = re.compile(r'.*--info-title--.*')
        info_text = re.compile(r'.*--info-text--.*')


        all = info.find_all('div', attrs={
                    'class': info_re
                })

        title_text={}
        for inform in all:
            key = inform.find('div', attrs={
                    'class': info_title
                }).text

            val = inform.find('div', attrs={
                    'class': info_text
                }).text
            title_text[key] = val

        return title_text
    
    def get_address(self):
        address = re.compile(r'.*--geo--.*')
        geo = self.soup.find('div', attrs={'class': address})
        tag = geo.find('span', attrs={'itemprop': 'name'}) 
        return tag['content']
    
    def get_undergrounds(self):
        undergrounds = re.compile(r'.*--underground--.*')

        all_undergrounds = self.soup.find_all('li', attrs={
            'class': undergrounds
        })

        und_str = str()
        for und in all_undergrounds:
            und_link_reg = re.compile(r'.*--underground_link--.*')
            und_time_reg = re.compile(r'.*--underground_time--.*')

            und_name = und.find('a', attrs={
                'class': und_link_reg
            }).text
            und_time = und.find('span', attrs={
                'class': und_time_reg
            })
            
            if und_time is None:
                und_time = ''
            else:
                und_time = und_time.text[4:]
            
            und_str += und_name + ' ' + und_time + ' '

        return und_str
    
    def house_properties(self):
        house_dict={}
        for item in self.soup.find_all('div', attrs= {'class': re.compile(r'.*--item--.*')}):
            house_attr_name = item.find('div', attrs = {'class': re.compile('.*--name--.*')}).text
            house_attr_value = item.find('div', attrs = {'class': re.compile('.*--value--.*')}).text
            house_dict[house_attr_name] = house_attr_value
        return house_dict
    
    def get_flat_attrs(self):
        """
        Return list of values: [Можно с детьми, можно с животными]
        """
        tag_info = self.soup.find('div', attrs={'class': re.compile('.*--section_divider--.*')})
        tag_sections = tag_info.find_all('ul', attrs={'class': re.compile('.*--container--.*')})
        atrib = []
        for section in tag_sections:
            for x in section.find_all('li', attrs={'class': re.compile('.*--item--.*')}):
                atrib.append(x.text)
        return atrib
    
    def get_flat_properties(self):
    
        """
        Return dict of values: {Тип жилья: ..., Планировка:...}
        """
        dop_attrs = {}
        container = self.soup.find('article', re.compile('.*--container--.*'))
        item = container.find_all('li', re.compile('.*--item.*--'))
        for it in item:
            name = it.find('span', re.compile('.*--name--.*')).text
            value = it.find('span', re.compile('.*--value--.*')).text
            dop_attrs[name] = value
        return dop_attrs
    
    def get_short_description(self):
        terms = self.soup.find('div', attrs={'class':re.compile('.*terms.*')})
        return re.sub(r'\xa0', ' ',  terms.find('p', attrs={'class': re.compile('.*description.*')}).text)
    
    def get_main_description(self):
        return self.soup.find('p', attrs={'itemprop': 'description'}).text

# %%
m_p = main_page_parser(url = r'https://www.cian.ru/cat.php?deal_type=rent&engine_version=2&offer_type=flat&p=1&region=1&type=4',
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36',
          'Sec-Fetch-Mode': 'cors' })

# %%
f_p = flat_page_parser(url = r'https://www.cian.ru/rent/flat/215439272/',
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36',
          'Sec-Fetch-Mode': 'cors' })

# %%
f_p.address['content']
# Out:
# 'Москва, ЦАО, р-н Пресненский, наб. Пресненская, 8с1'

# %%
url = 'https://www.cian.ru/cat.php?deal_type=rent&engine_version=2&offer_type=flat&p=1&region=1&type=4'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36',
          'Sec-Fetch-Mode': 'cors' }

first_request = requests.get(url, headers=headers)
soup = BeautifulSoup(first_request.text)

# %%
total_offers = get_total_offers(soup)

# %%
total_pages = get_total_pages(total_offers)

# %%
# %%time
total_pages = 20
flat_df = pd.DataFrame()
for page_num in tqdm(range(10, total_pages+1)):
    url = r'https://www.cian.ru/cat.php?deal_type=rent&engine_version=2&offer_type=flat&p={}&region=1&type=4'.format(page_num)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36',
          'Sec-Fetch-Mode': 'cors' }
    mpp = main_page_parser(url, headers)
    
    for item in mpp.price.items():
        if item[0] not in flat_df.index:
            flat_df.loc[item[0], 'price'] = item[1]
            flat_df.loc[item[0], 'href'] = mpp.href[item[0]]
            
            fpp = flat_page_parser(mpp.href[item[0]], headers=headers)
            flat_df.loc[item[0], 'more_price_info'] = fpp.more_price_info
            
            for info in fpp.main_info.items():
                flat_df.loc[item[0], info[0]] = info[1]
            
            flat_df.loc[item[0], 'address'] = fpp.address
            
            flat_df.loc[item[0], 'undergrounds'] = fpp.undergrounds
            
            for hp in fpp.house.items():
                flat_df.loc[item[0], hp[0]] = hp[1]
            
            for flat_atr in fpp.flat_attrs:
                flat_df.loc[item[0], flat_atr] = 1
            
            for flat_prp in fpp.flat_properties.items():
                flat_df.loc[item[0], flat_prp[0]] = flat_prp[1]
                
            flat_df.loc[item[0], 'short_description'] = fpp.short_description
            flat_df.loc[item[0], 'main_description'] = fpp.main_description
            
        elif item[1] != flat_df.loc[item[0], 'price']:
            flat_df.loc[item[0], 'price'] = item[1]
            flat_df.loc[itemp[0], 'change_price'] = 1
# Out:
# Wall time: 3min 59s

# %%
total_pages
# Out:
# 860

# %%
flat_df
# Out:
#             price                                      href  \
# 209074866   55000  https://www.cian.ru/rent/flat/209074866/
# 213955093   65000  https://www.cian.ru/rent/flat/213955093/
# 212894519   75000  https://www.cian.ru/rent/flat/212894519/
# 204996621   75000  https://www.cian.ru/rent/flat/204996621/
# 211254455   79999  https://www.cian.ru/rent/flat/211254455/
# 214380553   80000  https://www.cian.ru/rent/flat/214380553/
# 211793992   80000  https://www.cian.ru/rent/flat/211793992/
# 211696644   83000  https://www.cian.ru/rent/flat/211696644/
# 210572665   85000  https://www.cian.ru/rent/flat/210572665/
# 213269803   86000  https://www.cian.ru/rent/flat/213269803/
# 210379680   90000  https://www.cian.ru/rent/flat/210379680/
# 215249118   90000  https://www.cian.ru/rent/flat/215249118/
# 159368110   90000  https://www.cian.ru/rent/flat/159368110/
# 213944755   90000  https://www.cian.ru/rent/flat/213944755/
# 211269046   96880  https://www.cian.ru/rent/flat/211269046/
# 213851731   97775  https://www.cian.ru/rent/flat/213851731/
# 213494874   99000  https://www.cian.ru/rent/flat/213494874/
# 200086413  100000  https://www.cian.ru/rent/flat/200086413/
# 198430229  100000  https://www.cian.ru/rent/flat/198430229/
# 215102328  100000  https://www.cian.ru/rent/flat/215102328/
# 213192589  100000  https://www.cian.ru/rent/flat/213192589/
# 210366067  105000  https://www.cian.ru/rent/flat/210366067/
# 209120011  110000  https://www.cian.ru/rent/flat/209120011/
# 212945531  110000  https://www.cian.ru/rent/flat/212945531/
# 212840542  110000  https://www.cian.ru/rent/flat/212840542/
# 214410813  110000  https://www.cian.ru/rent/flat/214410813/
# 201946768  118362  https://www.cian.ru/rent/flat/201946768/
# 214044869  120000  https://www.cian.ru/rent/flat/214044869/
# 214044875  120000  https://www.cian.ru/rent/flat/214044875/
# 204009177  120000  https://www.cian.ru/rent/flat/204009177/
# ...           ...                                       ...
# 207913702                         Нет       ...          Центральное
# 202914594              1 пассажирский       ...                  NaN
# 189317699              1 пассажирский       ...                  NaN
# 211084947              1 пассажирский       ...                  NaN
# 210598438                         Нет       ...                  NaN
# 203231018              1 пассажирский       ...          Центральное
#
#            Посудомоечная машина  Ванна            Планировка  Ванная комната  \
# 209074866                   NaN    NaN                   NaN             NaN
# 213955093                   1.0    1.0               Смежная            Есть
# 212894519                   1.0    NaN                   NaN             NaN
# 204996621                   1.0    1.0                   NaN            Есть
# 211254455                   NaN    NaN         Изолированная             NaN
# 214380553                   1.0    1.0                   NaN            Есть
# 211793992                   NaN    NaN         Изолированная             NaN
# 211696644                   1.0    NaN                   NaN             NaN
# 210572665                   1.0    1.0         Изолированная            Есть
# 213269803                   1.0    1.0                   NaN            Есть
# 210379680                   1.0    NaN                   NaN             NaN
# 215249118                   1.0    NaN                   NaN             NaN
# 159368110                   1.0    1.0                   NaN            Есть
# 213944755                   1.0    1.0                   NaN            Есть
# 211269046                   1.0    1.0         Изолированная            Есть
# 213851731                   1.0    1.0         Изолированная            Есть
# 213494874                   1.0    NaN                   NaN             NaN
# 200086413                   1.0    1.0               Смежная            Есть
# 198430229                   1.0    1.0                   NaN            Есть
# 215102328                   1.0    1.0         Изолированная            Есть
# 213192589                   1.0    NaN         Изолированная             NaN
# 210366067                   1.0    1.0                   NaN            Есть
# 209120011                   1.0    1.0                   NaN            Есть
# 212945531                   1.0    1.0                   NaN            Есть
# 212840542                   1.0    NaN         Изолированная             NaN
# 214410813                   1.0    NaN                   NaN             NaN
# 201946768                   1.0    1.0                   NaN            Есть
# 214044869                   1.0    NaN                   NaN             NaN
# 214044875                   1.0    NaN                   NaN             NaN
# 204009177                   1.0    1.0                   NaN            Есть
# ...                         ...    ...                   ...             ...
# 206690334                   NaN    1.0                   NaN            Есть
# 215188946                   NaN    1.0                   NaN            Есть
# 211806872                   1.0    1.0  Смежно-изолированная            Есть
# 207386967                   1.0    1.0  Смежно-изолированная            Есть
# 215020944                   1.0    1.0  Смежно-изолированная            Есть
# 198137233                   1.0    1.0  Смежно-изолированная            Есть
# 210383239                   1.0    1.0  Смежно-изолированная            Есть
# 213208972                   1.0    1.0  Смежно-изолированная            Есть
# 210884587                   NaN    NaN                   NaN             NaN
# 212720967                   1.0    1.0                   NaN            Есть
# 199443180                   1.0    1.0                   NaN            Есть
# 205771376                   1.0    1.0  Смежно-изолированная            Есть
# 205754078                   1.0    1.0  Смежно-изолированная            Есть
# 208706730                   1.0    1.0  Смежно-изолированная            Есть
# 211518902                   1.0    1.0  Смежно-изолированная            Есть
# 210568003                   NaN    1.0  Смежно-изолированная            Есть
# 211619154                   1.0    1.0  Смежно-изолированная            Есть
# 210383298                   1.0    1.0  Смежно-изолированная            Есть
# 207855587                   1.0    1.0  Смежно-изолированная            Есть
# 210852681                   1.0    1.0  Смежно-изолированная            Есть
# 214547098                   1.0    1.0  Смежно-изолированная            Есть
# 213229096                   1.0    1.0  Смежно-изолированная            Есть
# 215442840                   1.0    1.0  Смежно-изолированная            Есть
# 215421010                   1.0    1.0  Смежно-изолированная            Есть
# 207913702                   1.0    1.0                   NaN            Есть
# 202914594                   1.0    1.0  Смежно-изолированная            Есть
# 189317699                   1.0    1.0  Смежно-изолированная            Есть
# 211084947                   1.0    1.0  Смежно-изолированная            Есть
# 210598438                   NaN    NaN                   NaN             NaN
# 203231018                   1.0    1.0  Смежно-изолированная            Есть
#
#                 Балкон/лоджия      Вид из окон  Построен  Мусоропровод  \
# 209074866                 NaN              NaN       NaN           NaN
# 213955093            1 балкон          Во двор       NaN           NaN
# 212894519            1 балкон         На улицу      1964          Есть
# 204996621            1 балкон          Во двор       NaN          Есть
# 211254455                 NaN              NaN       NaN           Нет
# 214380553           2 балкона          Во двор       NaN           Нет
# 211793992            1 лоджия              NaN      2010          Есть
# 211696644                 NaN  На улицу и двор      1951           NaN
# 210572665            1 лоджия              NaN      2008          Есть
# 213269803            2 лоджии          Во двор      1971          Есть
# 210379680                 NaN  На улицу и двор       NaN           NaN
# 215249118                 NaN          Во двор       NaN           NaN
# 159368110            1 лоджия          Во двор      2011          Есть
# 213944755            1 лоджия          Во двор       NaN           Нет
# 211269046                 NaN          Во двор       NaN          Есть
# 213851731                 NaN          Во двор       NaN           NaN
# 213494874                 NaN          Во двор      1975           NaN
# 200086413            1 балкон         На улицу      2012          Есть
# 198430229            1 балкон              NaN      2012          Есть
# 215102328            1 балкон              NaN       NaN           NaN
# 213192589                 NaN         На улицу       NaN           Нет
# 210366067                 NaN         На улицу      2007          Есть
# 209120011            1 лоджия         На улицу       NaN          Есть
# 212945531                 NaN          Во двор       NaN           NaN
# 212840542            1 балкон  На улицу и двор       NaN          Есть
# 214410813                 NaN  На улицу и двор      1911           Нет
# 201946768            2 лоджии  На улицу и двор      1973           Нет
# 214044869            2 лоджии          Во двор       NaN           NaN
# 214044875                 NaN  На улицу и двор       NaN           NaN
# 204009177            1 балкон         На улицу      1947           Нет
# ...                       ...              ...       ...           ...
# 206690334            1 балкон          Во двор      1998          Есть
# 215188946  1 балкон, 1 лоджия          Во двор       NaN          Есть
# 211806872            1 балкон  На улицу и двор       NaN           NaN
# 207386967                 NaN  На улицу и двор       NaN           NaN
# 215020944                 NaN  На улицу и двор       NaN           NaN
# 198137233                 NaN  На улицу и двор       NaN           NaN
# 210383239                 NaN  На улицу и двор       NaN           NaN
# 213208972                 NaN  На улицу и двор       NaN           NaN
# 210884587            2 лоджии  На улицу и двор      2002           NaN
# 212720967            1 балкон          Во двор      1914           NaN
# 199443180                 NaN          Во двор      1910           Нет
# 205771376                 NaN  На улицу и двор       NaN           NaN
# 205754078            1 балкон  На улицу и двор       NaN           NaN
# 208706730            1 балкон  На улицу и двор       NaN           NaN
# 211518902            1 балкон  На улицу и двор       NaN           NaN
# 210568003                 NaN  На улицу и двор       NaN           NaN
# 211619154                 NaN  На улицу и двор       NaN           NaN
# 210383298            1 балкон  На улицу и двор       NaN           NaN
# 207855587                 NaN  На улицу и двор       NaN           NaN
# 210852681            1 балкон  На улицу и двор       NaN           NaN
# 214547098                 NaN  На улицу и двор       NaN           NaN
# 213229096                 NaN  На улицу и двор       NaN           NaN
# 215442840            1 балкон  На улицу и двор       NaN           NaN
# 215421010                 NaN  На улицу и двор       NaN           NaN
# 207913702                 NaN          Во двор       NaN           Нет
# 202914594            1 балкон  На улицу и двор       NaN           NaN
# 189317699                 NaN  На улицу и двор       NaN           NaN
# 211084947            1 балкон  На улицу и двор       NaN           NaN
# 210598438                 NaN          Во двор       NaN           NaN
# 203231018                 NaN  На улицу и двор       NaN           NaN
#
#            Высота потолков
# 209074866              NaN
# 213955093              NaN
# 212894519              NaN
# 204996621            2,7 м
# 211254455              0 м
# 214380553              NaN
# 211793992              NaN
# 211696644              NaN
# 210572665              NaN
# 213269803            2,8 м
# 210379680            2,8 м
# 215249118              NaN
# 159368110              NaN
# 213944755              NaN
# 211269046            2,8 м
# 213851731              NaN
# 213494874              NaN
# 200086413              NaN
# 198430229              NaN
# 215102328              NaN
# 213192589            3,1 м
# 210366067            2,9 м
# 209120011              3 м
# 212945531              NaN
# 212840542              0 м
# 214410813            2,8 м
# 201946768            2,9 м
# 214044869              NaN
# 214044875              NaN
# 204009177            3,5 м
# ...                    ...
# 206690334           2,75 м
# 215188946              NaN
# 211806872            3,2 м
# 207386967            3,2 м
# 215020944            3,2 м
# 198137233            3,2 м
# 210383239            3,2 м
# 213208972            3,2 м
# 210884587              NaN
# 212720967              NaN
# 199443180            3,5 м
# 205771376            3,2 м
# 205754078            3,2 м
# 208706730            3,2 м
# 211518902            3,2 м
# 210568003            3,2 м
# 211619154            3,2 м
# 210383298            3,2 м
# 207855587            3,2 м
# 210852681            3,2 м
# 214547098            3,2 м
# 213229096            3,2 м
# 215442840            3,2 м
# 215421010            3,2 м
# 207913702            3,2 м
# 202914594            3,2 м
# 189317699            3,2 м
# 211084947            3,2 м
# 210598438              NaN
# 203231018            3,2 м
#
# [322 rows x 44 columns]

# %%
flat_df[['Год постройки', 'Построен', 'href']]
# Out:
#           Год постройки Построен                                      href
# 207924378          2016      NaN  https://www.cian.ru/rent/flat/207924378/
# 214537449          2016      NaN  https://www.cian.ru/rent/flat/214537449/
# 186778851          2016      NaN  https://www.cian.ru/rent/flat/186778851/
# 215078648          2016      NaN  https://www.cian.ru/rent/flat/215078648/
# 151978998           NaN     2011  https://www.cian.ru/rent/flat/151978998/
# 214625671          2016      NaN  https://www.cian.ru/rent/flat/214625671/
# 207957981          2015      NaN  https://www.cian.ru/rent/flat/207957981/
# 214092509           NaN      NaN  https://www.cian.ru/rent/flat/214092509/
# 215229448           NaN      NaN  https://www.cian.ru/rent/flat/215229448/
# 208582656          2016      NaN  https://www.cian.ru/rent/flat/208582656/
# 215600664           NaN      NaN  https://www.cian.ru/rent/flat/215600664/
# 204575572          2014     2014  https://www.cian.ru/rent/flat/204575572/
# 213968655          2016      NaN  https://www.cian.ru/rent/flat/213968655/
# 215192806          2016      NaN  https://www.cian.ru/rent/flat/215192806/
# 215194092          2016      NaN  https://www.cian.ru/rent/flat/215194092/
# 215439272           NaN      NaN  https://www.cian.ru/rent/flat/215439272/
# 212129239           NaN      NaN  https://www.cian.ru/rent/flat/212129239/
# 211103002           NaN     2009  https://www.cian.ru/rent/flat/211103002/
# 212164160           NaN      NaN  https://www.cian.ru/rent/flat/212164160/
# 215163587           NaN     2009  https://www.cian.ru/rent/flat/215163587/
# 214064668           NaN      NaN  https://www.cian.ru/rent/flat/214064668/
# 194317729           NaN      NaN  https://www.cian.ru/rent/flat/194317729/
# 195519946           NaN     2009  https://www.cian.ru/rent/flat/195519946/
# 207948065          1967     1967  https://www.cian.ru/rent/flat/207948065/
# 195298281          1967     1967  https://www.cian.ru/rent/flat/195298281/
# 215536932          2016      NaN  https://www.cian.ru/rent/flat/215536932/
# 215570168           NaN     2009  https://www.cian.ru/rent/flat/215570168/
# 214710173           NaN     2012  https://www.cian.ru/rent/flat/214710173/

# %%
flat_df.loc['204575572', :]
# Out:
# price                                                                                                                      220000
# href                                                                                     https://www.cian.ru/rent/flat/204575572/
# more_price_info                                                                            Комм. платежи включены (без счётчиков)
# Общая                                                                                                                      171 м²
# Жилая                                                                                                                      119 м²
# Кухня                                                                                                                       15 м²
# Этаж                                                                                                                     27 из 32
# address                                                                         Москва, ЮЗАО, р-н Обручевский, Ленинский просп...
# undergrounds                                                                    Проспект Вернадского 27 мин. пешком Юго-Западн...
# Год постройки                                                                                                                2014
# Тип дома                                                                                                               Монолитный
# Лифты                                                                                                  1 пассажирский, 1 грузовой
# Парковка                                                                                                                Подземная
# Мусоропровод                                                                                                                 Есть
# Холодильник                                                                                                                     1
# Посудомоечная машина                                                                                                            1
# Стиральная машина                                                                                                               1
# Мебель в комнатах                                                                                                               1
# Мебель на кухне                                                                                                                 1
# Кондиционер                                                                                                                     1
# Телевизор                                                                                                                       1
# Интернет                                                                                                                        1
# Ванна                                                                                                                           1
# Душевая кабина                                                                                                                  1
# Тип жилья                                                                                                                     NaN
# Площадь комнат+ обозначение смежных комнат- обозначение изолированных комнат                                               119 м²
# Высота потолков                                                                                                               NaN
# Санузел                                                                                                             3 совмещенных
# Ванная комната                                                                                                               Есть
# Ремонт                                                                                                               Дизайнерский
# Вид из окон                                                                                                       На улицу и двор
# short_description                                                               Залог 220 000 ₽, без комиссии, предоплата за 1...
# main_description                                                                В аренду предлагается 4-х комнатная квартира с...
# Можно с детьми                                                                                                                  1
# Можно с животными                                                                                                               1
# Планировка                                                                                                                    NaN
# Построен                                                                                                                     2014
# Тип перекрытий                                                                                                     Железобетонные
# Подъезды                                                                                                                        4
# Отопление                                                                                                             Центральное
# Аварийность                                                                                                                   Нет
# Балкон/лоджия                                                                                                 2 балкона, 3 лоджии
# Name: 204575572, dtype: object

# %%
flat_df
# Out:
#             price                                      href  \
# 207924378  200000  https://www.cian.ru/rent/flat/207924378/
# 214537449  250000  https://www.cian.ru/rent/flat/214537449/
# 186778851  199900  https://www.cian.ru/rent/flat/186778851/
нас: ТОЛЬКО РЕАЛЬНО СУЩЕСТВУЮЩИЕ ОБ...            NaN
# 214537449  Лот 708. Агентам солидный бонус. БАШНЯ ОКО. Ую...            1.0
# 186778851  СУПЕР-ЦЕНА! ОПЕРАТИВНЫЙ ПОКАЗ! ЗВОНИТЕ!БЕЗ КОМ...            1.0
# 215078648  Апартаменты с отделкой в башне ОКО. 2-х комнат...            1.0
# 151978998  Собственник сдает апартаменты в аренду по прям...            1.0
# 214625671  О нас: ТОЛЬКО РЕАЛЬНО СУЩЕСТВУЮЩИЕ ОБЪЕКТЫ!!! ...            NaN
# 207957981  МАКСИМАЛЬНЫЙ БОНУС АГЕНТУ! Предлагается таунха...            1.0
# 214092509  О нас: ТОЛЬКО РЕАЛЬНО СУЩЕСТВУЮЩИЕ ОБЪЕКТЫ!!! ...            NaN
# 215229448  О нас: ТОЛЬКО РЕАЛЬНО СУЩЕСТВУЮЩИЕ ОБЪЕКТЫ!!! ...            NaN
# 208582656  Лот 035. О нас: ТОЛЬКО РЕАЛЬНО СУЩЕСТВУЮЩИЕ ОБ...            NaN
# 213968655  id: 538072 БЕЗ КОМИССИИ ДЛЯ АРЕНДАТОРА! МФК ОК...            NaN
# 204575572  В аренду предлагается 4-х комнатная квартира с...            1.0
# 194317729  Сдаётся ВПЕРВЫЕ уникальная двухуровневая с пан...            1.0
# 215192806  | Комиссии для клиента 0% | Бонус Клиентам - К...            1.0
# 215194092  | Комиссии для клиента 0% | Бонус Клиентам - К...            1.0
# 215439272  id: 539115 Аренда 3-комнатных апартаментов пло...            NaN
# 212129239                                                NaN            NaN
#
#           Можно с животными     Планировка Построен  Тип перекрытий Подъезды  \
# 207924378               NaN            NaN      NaN             NaN      NaN
# 214537449               1.0  Изолированная      NaN             NaN      NaN
# 186778851               1.0            NaN      NaN             NaN      NaN
# 215078648               1.0            NaN      NaN             NaN      NaN
# 151978998               1.0            NaN     2011             NaN      NaN
# 214625671               NaN            NaN      NaN             NaN      NaN
# 207957981               1.0  Изолированная      NaN             NaN      NaN
# 214092509               NaN            NaN      NaN             NaN      NaN
# 215229448               NaN            NaN      NaN             NaN      NaN
# 208582656               NaN            NaN      NaN             NaN      NaN
# 213968655               NaN            NaN      NaN             NaN      NaN
# 204575572               1.0            NaN     2014  Железобетонные        4
# 194317729               1.0            NaN      NaN             NaN      NaN
# 215192806               1.0            NaN      NaN             NaN      NaN
# 215194092               1.0            NaN      NaN             NaN      NaN
# 215439272               NaN            NaN      NaN             NaN      NaN
# 212129239               NaN            NaN      NaN             NaN      NaN
#
#              Отопление  Аварийность        Балкон/лоджия
# 207924378          NaN          NaN                  NaN
# 214537449          NaN          NaN                  NaN
# 186778851          NaN          NaN                  NaN
# 215078648          NaN          NaN                  NaN
# 151978998          NaN          NaN                  NaN
# 214625671          NaN          NaN                  NaN
# 207957981          NaN          NaN                  NaN
# 214092509          NaN          NaN                  NaN
# 215229448          NaN          NaN                  NaN
# 208582656          NaN          NaN                  NaN
# 213968655          NaN          NaN                  NaN
# 204575572  Центральное          Нет  2 балкона, 3 лоджии
# 194317729          NaN          NaN                  NaN
# 215192806          NaN          NaN                  NaN
# 215194092          NaN          NaN                  NaN
# 215439272          NaN          NaN                  NaN
# 212129239          NaN          NaN                  NaN
#
# [17 rows x 46 columns]

# %%
soup = BeautifulSoup(requests.get('https://www.cian.ru/rent/flat/207924378/').text)

# %%
# Out:
# 'Лот 013. О нас: ТОЛЬКО РЕАЛЬНО СУЩЕСТВУЮЩИЕ ОБЪЕКТЫ!!!  ИХ МОЖНО ПОСМОТРЕТЬ СЕГОДНЯ!!! Мы в сити 24/7. Оперативный показ в любое удобное время. English  WhatsApp, Telegram, Viber. Агентам солидный бонус.Описание объекта: БАШНЯ Око. Уютная стандартная отделка. Апартаменты полностью укомплектованы мебелью и всей необходимой техникой бытовой и кухонной техникой. Функциональная планировка: Кухня-студия, совмещенная с просторной гостиной, спальня с собственной ванной и сан.узлом (сан.узлы так же полностью укомплектованы (См. фото)), просторный холл, постирочная и сушильная зона. Панорамное остекление по всему периметру апартаментов. Видовые характеристики: футуристический вид на город. В ночное время огни небоскребов никого не оставят равнодушными. Москва Сити - это Москва будущего, строящийся международный деловой квартал из ультрасовременных небоскрёбов. Уникальная для России и Восточной Европы зона деловой активности объединяет в себе апартаменты для жилья, офисные здания, многочисленные площадки для торговли и отдыха. Москвичей и гостей города Москва-Сити привлекает необычной конфигурацией сооружений, развитой социально-культурной инфраструктурой, здесь можно посетить бутики, спа-салоны, рестораны, клубы, выставочные галереи, развлекательные центры. Создатели комплекса стремились не просто выстроить небоскрёбы, а сделать так, чтобы они органично вписались в ансамбль исторических памятников. Москва-Сити это город в городе, архитектура которого сочетает в себе хай-тек, модерн и неоконструктивизм. Неповторимый облик делового центра, а также возможность полюбоваться столицей с головокружительной высоты неизменно привлекают сюда туристов со всего мира.'

# %%
''.join(re.findall(r'\d+', '23 267 предложений\xa0отсортированы\xa0По умолчанию'))
# Out:
# '23267'

# %%
# %%time

for p in range(1,11):

    
    

    #По каждой квартире получаем основную информацию
    for room in room_url_list:
        #Записываем id квартиры и ссылку на нее
        room_id = re.search(r'[0-9]+',room.attrs['href']).group()
        flat_df.loc[room_id, 'ref'] = room.attrs['href'] 

        flat_html = requests.get(room.attrs['href'], headers=headers)
        bs_flat = BeautifulSoup(flat_html.text)
        print(flat_html)
        flat_df.loc[room_id, 'price'] = get_price(bs_flat)
        flat_df.loc[room_id, 'price_info'] = get_more_price_info(bs_flat)
        
        main_info = get_main_info(bs_flat)
        for main_info_col in main_info:
            flat_df.loc[room_id, main_info_col] = main_info[main_info_col]
            
        #address = get_address(bs_flat)
        #for add_part in address:
        #   flat_df.loc[room_id, add_part] = address[add_part]
        flat_df.loc[room_id, 'address'] = get_address_new(bs_flat)
        time.sleep(5)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-25-8fee26654780> in get_price(bs_flat)
#       1 def get_price(bs_flat):
#       2     return re.sub(r'\xa0','', bs_flat.find('span', attrs={
# ----> 3                 'itemprop':'price'
#       4             }).attrs['content']).replace('₽/мес.','')
#       5
#
# AttributeError: 'NoneType' object has no attribute 'attrs'
